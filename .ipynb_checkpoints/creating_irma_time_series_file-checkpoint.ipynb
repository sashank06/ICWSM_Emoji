# %%
import pandas as pd
import numpy as np
import re
import itertools

# %%
df_tweets = pd.read_csv("/Volumes/GoogleDrive/My Drive/Solidarity_analysis/RVisTutorial-master/sashank_viz/irma_analysis_files/irma/processed/irma_text_convverted.csv")
df_emojis = pd.read_csv("/Volumes/GoogleDrive/My Drive/Solidarity_analysis/RVisTutorial-master/sashank_viz/irma_analysis_files/irma/processed/emoji_dict.csv")

# %%
df_emojis = df_emojis.rename(columns={'r.encoding': 'encoding'})

# %%
emoji_dict = dict(zip(df_emojis.encoding,df_emojis.description))

# %%
emoji_dict
# Out:
# {'<f0><9f><98><80>': 'grinning face',
#  '<f0><9f><98><81>': 'grinning face with smiling eyes',
#  '<f0><9f><98><82>': 'face with tears of joy',
#  '<f0><9f><a4><a3>': 'rolling on the floor laughing',
#  '<f0><9f><98><83>': 'smiling face with open mouth',
#  '<f0><9f><98><84>': 'smiling face with open mouth &amp- smiling eyes',
#  '<f0><9f><98><85>': 'smiling face with open mouth &amp- cold sweat',
#  '<f0><9f><98><86>': 'smiling face with open mouth &amp- closed eyes',
#  '<f0><9f><98><89>': 'winking face',
#  '<f0><9f><98><8a>': 'smiling face with smiling eyes',
#  '<f0><9f><98><8b>': 'face savouring delicious food',
#  '<f0><9f><98><8e>': 'smiling face with sunglasses',
#  '<f0><9f><98><8d>': 'smiling face with heart-eyes',
#  '<f0><9f><98><98>': 'face blowing a kiss',
#  '<f0><9f><98><97>': 'kissing face',
#  '<f0><9f><98><99>': 'kissing face with smiling eyes',
#  '<f0><9f><98><9a>': 'kissing face with closed eyes',
#  '<e2><98><ba>': 'smiling face',
#  '<f0><9f><99><82>': 'slightly smiling face',
#  '<f0><9f><a4><97>': 'hugging face',
#  '<f0><9f><a4><94>': 'thinking face',
#  '<f0><9f><98><90>': 'neutral face',
#  '<f0><9f><98><91>': 'expressionless face',
#  '<f0><9f><98><b6>': 'face without mouth',
#  '<f0><9f><99><84>': 'face with rolling eyes',
#  '<f0><9f><98><8f>': 'smirking face',
#  '<f0><9f><98><a3>': 'persevering face',
#  '<f0><9f><98><a5>': 'disappointed but relieved face',
#  '<f0><9f><98><ae>': 'face with open mouth',
#  '<f0><9f><a4><90>': 'zipper-mouth face',
#  '<f0><9f><98><af>': 'hushed face',
#  '<f0><9f><98><aa>': 'sleepy face',
#  '<f0><9f><98><ab>': 'tired face',
#  '<f0><9f><98><b4>': 'sleeping face',
#  '<f0><9f><98><8c>': 'relieved face',
#  '<f0><9f><a4><93>': 'nerd face',
#  '<f0><9f><98><9b>': 'face with stuck-out tongue',
#  '<f0><9f><98><9c>': 'face with stuck-out tongue &amp- winking eye',
#  '<f0><9f><98><9d>': 'face with stuck-out tongue &amp- closed eyes',
#  '<f0><9f><a4><a4>': 'drooling face',
#  '<f0><9f><98><92>': 'unamused face',
#  '<f0><9f><98><93>': 'face with cold sweat',
#  '<f0><9f><98><94>': 'pensive face',
#  '<f0><9f><98><95>': 'confused face',
#  '<f0><9f><99><83>': 'upside-down face',
#  '<f0><9f><a4><91>': 'money-mouth face',
#  '<f0><9f><98><b2>': 'astonished face',
#  '<e2><98><b9>': 'frowning face',
#  '<f0><9f><99><81>': 'slightly frowning face',
#  '<f0><9f><98><96>': 'confounded face',
#  '<f0><9f><98><9e>': 'disappointed face',
#  '<f0><9f><98><9f>': 'worried face',
#  '<f0><9f><98><a4>': 'face with steam from nose',
#  '<f0><9f><98><a2>': 'crying face',
#  '<f0><9f><98><ad>': 'loudly crying face',
#  '<f0><9f><98><a6>': 'frowning face with open mouth',
#  '<f0><9f><98><a7>': 'anguished face',
#  '<f0><9f><98><a8>': 'fearful face',
#  '<f0><9f><98><a9>': 'weary face',
#  '<f0><9f><98><ac>': 'grimacing face',
#  '<f0><9f><98><b0>': 'face with open mouth &amp- cold sweat',
#  '<f0><9f><98><b1>': 'face screaming in fear',
#  '<f0><9f><98><b3>': 'flushed face',
#  '<f0><9f><98><b5>': 'dizzy face',
#  '<f0><9f><98><a1>': 'pouting face',
#  '<f0><9f><98><a0>': 'angry face',
#  '<f0><9f><98><87>': 'smiling face with halo',
#  '<f0><9f><a4><a0>': 'cowboy hat face',
#  '<f0><9f><a4><a1>': 'clown face',
#  '<f0><9f><a4><a5>': 'lying face',
#  '<f0><9f><98><b7>': 'face with medical mask',
#  '<f0><9f><a4><92>': 'face with thermometer',
#  '<f0><9f><a4><95>': 'face with head-bandage',
#  '<f0><9f><a4><a2>': 'nauseated face',
#  '<f0><9f><a4><a7>': 'sneezing face',
#  '<f0><9f><98><88>': 'smiling face with horns',
#  '<f0><9f><91><bf>': 'angry face with horns',
#  '<f0><9f><91><b9>': 'ogre',
#  '<f0><9f><91><ba>': 'goblin',
#  '<f0><9f><92><80>': 'skull',
#  '<e2><98><a0>': 'skull and crossbones',
#  '<f0><9f><91><bb>': 'ghost',
#  '<f0><9f><91><bd>': 'alien',
#  '<f0><9f><91><be>': 'alien monster',
#  '<f0><9f><a4><96>': 'robot face',
#  '<f0><9f><92><a9>': 'pile of poo',
#  '<f0><9f><98><ba>': 'smiling cat face with open mouth',
#  '<f0><9f><98><b8>': 'grinning cat face with smiling eyes',
#  '<f0><9f><98><b9>': 'cat face with tears of joy',
#  '<f0><9f><98><bb>': 'smiling cat face with heart-eyes',
#  '<f0><9f><98><bc>': 'cat face with wry smile',
#  '<f0><9f><98><bd>': 'kissing cat face with closed eyes',
#  '<f0><9f><99><80>': 'weary cat face',
#  '<f0><9f><98><bf>': 'crying cat face',
#  '<f0><9f><98><be>': 'pouting cat face',
#  '<f0><9f><99><88>': 'see-no-evil monkey',
#  '<f0><9f><99><89>': 'hear-no-evil monkey',
#  '<f0><9f><99><8a>': 'speak-no-evil monkey',
#  '<f0><9f><91><a6>': 'boy',
#  '<f0><9f><91><a7>': 'girl',
#  '<f0><9f><91><a8>': 'man',
#  '<f0><9f><91><a9>': 'woman',
#  '<f0><9f><91><b4>': 'old man',
#  '<f0><9f><91><b5>': 'old woman',
#  '<f0><9f><91><b6>': 'baby',
#  '<f0><9f><91><bc>': 'baby angel',
#  '<f0><9f><91><a8><e2><80><8d><e2><9a><95><ef><b8><8f>': 'man health worker',
#  '<f0><9f><91><a9><e2><80><8d><e2><9a><95><ef><b8><8f>': 'woman health worker',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8e><93>': 'man student',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8e><93>': 'woman student',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8f><ab>': 'man teacher',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8f><ab>': 'woman teacher',
#  '<f0><9f><91><a8><e2><80><8d><e2><9a><96><ef><b8><8f>': 'man judge',
#  '<f0><9f><91><a9><e2><80><8d><e2><9a><96><ef><b8><8f>': 'woman judge',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8c><be>': 'man farmer',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8c><be>': 'woman farmer',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8d><b3>': 'man cook',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8d><b3>': 'woman cook',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><94><a7>': 'man mechanic',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><94><a7>': 'woman mechanic',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8f><ad>': 'man factory worker',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8f><ad>': 'woman factory worker',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><92><bc>': 'man office worker',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><92><bc>': 'woman office worker',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><94><ac>': 'man scientist',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><94><ac>': 'woman scientist',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><92><bb>': 'man technologist',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><92><bb>': 'woman technologist',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8e><a4>': 'man singer',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8e><a4>': 'woman singer',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><8e><a8>': 'man artist',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><8e><a8>': 'woman artist',
#  '<f0><9f><91><a8><e2><80><8d><e2><9c><88><ef><b8><8f>': 'man pilot',
#  '<f0><9f><91><a9><e2><80><8d><e2><9c><88><ef><b8><8f>': 'woman pilot',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><9a><80>': 'man astronaut',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><9a><80>': 'woman astronaut',
#  '<f0><9f><91><a8><e2><80><8d><f0><9f><9a><92>': 'man firefighter',
#  '<f0><9f><91><a9><e2><80><8d><f0><9f><9a><92>': 'woman firefighter',
#  '<f0><9f><91><ae>': 'police officer',
#  '<f0><9f><91><ae><e2><80><8d><e2><99><82><ef><b8><8f>': 'man police officer',
#  '<f0><9f><91><ae><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman police officer',
#  '<f0><9f><95><b5>': 'detective',
#  '<f0><9f><95><b5><ef><b8><8f><e2><80><8d><e2><99><82><ef><b8><8f>': 'man detective',
#  '<f0><9f><95><b5><ef><b8><8f><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman detective',
#  '<f0><9f><92><82>': 'guard',
#  '<f0><9f><92><82><e2><80><8d><e2><99><82><ef><b8><8f>': 'man guard',
#  '<f0><9f><92><82><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman guard',
#  '<f0><9f><91><b7>': 'construction worker',
#  '<f0><9f><91><b7><e2><80><8d><e2><99><82><ef><b8><8f>': 'man construction worker',
#  '<f0><9f><91><b7><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman construction worker',
#  '<f0><9f><91><b3>': 'person wearing turban',
#  '<f0><9f><91><b3><e2><80><8d><e2><99><82><ef><b8><8f>': 'man wearing turban',
#  '<f0><9f><91><b3><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman wearing turban',
#  '<f0><9f><91><b1>': 'blond-haired person',
#  '<f0><9f><91><b1><e2><80><8d><e2><99><82><ef><b8><8f>': 'blond-haired man',
#  '<f0><9f><91><b1><e2><80><8d><e2><99><80><ef><b8><8f>': 'blond-haired woman',
#  '<f0><9f><8e><85>': 'santa claus',
#  '<f0><9f><a4><b6>': 'mrs. claus',
#  '<f0><9f><91><b8>': 'princess',
#  '<f0><9f><a4><b4>': 'prince',
#  '<f0><9f><91><b0>': 'bride with veil',
#  '<f0><9f><a4><b5>': 'man in tuxedo',
#  '<f0><9f><a4><b0>': 'pregnant woman',
#  '<f0><9f><91><b2>': 'man with chinese cap',
#  '<f0><9f><99><8d>': 'person frowning',
#  '<f0><9f><99><8d><e2><80><8d><e2><99><82><ef><b8><8f>': 'man frowning',
#  '<f0><9f><99><8d><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman frowning',
#  '<f0><9f><99><8e>': 'person pouting',
#  '<f0><9f><99><8e><e2><80><8d><e2><99><82><ef><b8><8f>': 'man pouting',
#  '<f0><9f><99><8e><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman pouting',
#  '<f0><9f><99><85>': 'person gesturing no',
#  '<f0><9f><99><85><e2><80><8d><e2><99><82><ef><b8><8f>': 'man gesturing no',
#  '<f0><9f><99><85><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman gesturing no',
#  '<f0><9f><99><86>': 'person gesturing ok',
#  '<f0><9f><99><86><e2><80><8d><e2><99><82><ef><b8><8f>': 'man gesturing ok',
#  '<f0><9f><99><86><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman gesturing ok',
#  '<f0><9f><92><81>': 'person tipping hand',
#  '<f0><9f><92><81><e2><80><8d><e2><99><82><ef><b8><8f>': 'man tipping hand',
#  '<f0><9f><92><81><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman tipping hand',
#  '<f0><9f><99><8b>': 'person raising hand',
#  '<f0><9f><99><8b><e2><80><8d><e2><99><82><ef><b8><8f>': 'man raising hand',
#  '<f0><9f><99><8b><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman raising hand',
#  '<f0><9f><99><87>': 'person bowing',
#  '<f0><9f><99><87><e2><80><8d><e2><99><82><ef><b8><8f>': 'man bowing',
#  '<f0><9f><99><87><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman bowing',
#  '<f0><9f><a4><a6>': 'person facepalming',
#  '<f0><9f><a4><a6><e2><80><8d><e2><99><82><ef><b8><8f>': 'man facepalming',
#  '<f0><9f><a4><a6><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman facepalming',
#  '<f0><9f><a4><b7>': 'person shrugging',
#  '<f0><9f><a4><b7><e2><80><8d><e2><99><82><ef><b8><8f>': 'man shrugging',
#  '<f0><9f><a4><b7><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman shrugging',
#  '<f0><9f><92><86>': 'person getting massage',
#  '<f0><9f><92><86><e2><80><8d><e2><99><82><ef><b8><8f>': 'man getting massage',
#  '<f0><9f><92><86><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman getting massage',
#  '<f0><9f><92><87>': 'person getting haircut',
#  '<f0><9f><92><87><e2><80><8d><e2><99><82><ef><b8><8f>': 'man getting haircut',
#  '<f0><9f><92><87><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman getting haircut',
#  '<f0><9f><9a><b6>': 'person walking',
#  '<f0><9f><9a><b6><e2><80><8d><e2><99><82><ef><b8><8f>': 'man walking',
#  '<f0><9f><9a><b6><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman walking',
#  '<f0><9f><8f><83>': 'person running',
#  '<f0><9f><8f><83><e2><80><8d><e2><99><82><ef><b8><8f>': 'man running',
#  '<f0><9f><8f><83><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman running',
#  '<f0><9f><92><83>': 'woman dancing',
#  '<f0><9f><95><ba>': 'man dancing',
#  '<f0><9f><91><af>': 'people with bunny ears partying',
#  '<f0><9f><91><af><e2><80><8d><e2><99><82><ef><b8><8f>': 'men with bunny ears partying',
#  '<f0><9f><91><af><e2><80><8d><e2><99><80><ef><b8><8f>': 'women with bunny ears partying',
#  '<f0><9f><95><b4>': 'man in business suit levitating',
#  '<f0><9f><97><a3>': 'speaking head',
#  '<f0><9f><91><a4>': 'bust in silhouette',
#  '<f0><9f><91><a5>': 'busts in silhouette',
#  '<f0><9f><a4><ba>': 'person fencing',
#  '<f0><9f><8f><87>': 'horse racing',
#  '<e2><9b><b7>': 'skier',
#  '<f0><9f><8f><82>': 'snowboarder',
#  '<f0><9f><8f><8c>': 'person golfing',
#  '<f0><9f><8f><8c><ef><b8><8f><e2><80><8d><e2><99><82><ef><b8><8f>': 'man golfing',
#  '<f0><9f><8f><8c><ef><b8><8f><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman golfing',
#  '<f0><9f><8f><84>': 'person surfing',
#  '<f0><9f><8f><84><e2><80><8d><e2><99><82><ef><b8><8f>': 'man surfing',
#  '<f0><9f><8f><84><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman surfing',
#  '<f0><9f><9a><a3>': 'person rowing boat',
#  '<f0><9f><9a><a3><e2><80><8d><e2><99><82><ef><b8><8f>': 'man rowing boat',
#  '<f0><9f><9a><a3><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman rowing boat',
#  '<f0><9f><8f><8a>': 'person swimming',
#  '<f0><9f><8f><8a><e2><80><8d><e2><99><82><ef><b8><8f>': 'man swimming',
#  '<f0><9f><8f><8a><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman swimming',
#  '<e2><9b><b9>': 'person bouncing ball',
#  '<e2><9b><b9><ef><b8><8f><e2><80><8d><e2><99><82><ef><b8><8f>': 'man bouncing ball',
#  '<e2><9b><b9><ef><b8><8f><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman bouncing ball',
#  '<f0><9f><8f><8b>': 'person lifting weights',
#  '<f0><9f><8f><8b><ef><b8><8f><e2><80><8d><e2><99><82><ef><b8><8f>': 'man lifting weights',
#  '<f0><9f><8f><8b><ef><b8><8f><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman lifting weights',
#  '<f0><9f><9a><b4>': 'person biking',
#  '<f0><9f><9a><b4><e2><80><8d><e2><99><82><ef><b8><8f>': 'man biking',
#  '<f0><9f><9a><b4><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman biking',
#  '<f0><9f><9a><b5>': 'person mountain biking',
#  '<f0><9f><9a><b5><e2><80><8d><e2><99><82><ef><b8><8f>': 'man mountain biking',
#  '<f0><9f><9a><b5><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman mountain biking',
#  '<f0><9f><8f><8e>': 'racing car',
#  '<f0><9f><8f><8d>': 'motorcycle',
#  '<f0><9f><a4><b8>': 'person cartwheeling',
#  '<f0><9f><a4><b8><e2><80><8d><e2><99><82><ef><b8><8f>': 'man cartwheeling',
#  '<f0><9f><a4><b8><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman cartwheeling',
#  '<f0><9f><a4><bc>': 'people wrestling',
#  '<f0><9f><a4><bc><e2><80><8d><e2><99><82><ef><b8><8f>': 'men wrestling',
#  '<f0><9f><a4><bc><e2><80><8d><e2><99><80><ef><b8><8f>': 'women wrestling',
#  '<f0><9f><a4><bd>': 'person playing water polo',
#  '<f0><9f><a4><bd><e2><80><8d><e2><99><82><ef><b8><8f>': 'man playing water polo',
#  '<f0><9f><a4><bd><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman playing water polo',
#  '<f0><9f><a4><be>': 'person playing handball',
#  '<f0><9f><a4><be><e2><80><8d><e2><99><82><ef><b8><8f>': 'man playing handball',
#  '<f0><9f><a4><be><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman playing handball',
#  '<f0><9f><a4><b9>': 'person juggling',
#  '<f0><9f><a4><b9><e2><80><8d><e2><99><82><ef><b8><8f>': 'man juggling',
#  '<f0><9f><a4><b9><e2><80><8d><e2><99><80><ef><b8><8f>': 'woman juggling',
#  '<f0><9f><91><ab>': 'man and woman holding hands',
#  '<f0><9f><91><ac>': 'two men holding hands',
#  '<f0><9f><91><ad>': 'two women holding hands',
#  '<f0><9f><92><8f>': 'kiss',
#  '<f0><9f><92><91>': 'couple with heart',
#  '<f0><9f><91><aa>': 'family',
#  '<f0><9f><92><aa>': 'flexed biceps',
#  '<f0><9f><a4><b3>': 'selfie',
#  '<f0><9f><91><88>': 'backhand index pointing left',
#  '<f0><9f><91><89>': 'backhand index pointing right',
#  '<e2><98><9d>': 'index pointing up',
#  '<f0><9f><91><86>': 'backhand index pointing up',
#  '<f0><9f><96><95>': 'middle finger',
#  '<f0><9f><91><87>': 'backhand index pointing down',
#  '<e2><9c><8c>': 'victory hand',
#  '<f0><9f><a4><9e>': 'crossed fingers',
#  '<f0><9f><96><96>': 'vulcan salute',
#  '<f0><9f><a4><98>': 'sign of the horns',
#  '<f0><9f><a4><99>': 'call me hand',
#  '<f0><9f><96><90>': 'raised hand with fingers splayed',
#  '<e2><9c><8b>': 'raised hand',
#  '<f0><9f><91><8c>': 'ok hand',
#  '<f0><9f><91><8d>': 'thumbs up',
#  '<f0><9f><91><8e>': 'thumbs down',
#  '<e2><9c><8a>': 'raised fist',
#  '<f0><9f><91><8a>': 'oncoming fist',
#  '<f0><9f><a4><9b>': 'left-facing fist',
#  '<f0><9f><a4><9c>': 'right-facing fist',
#  '<f0><9f><a4><9a>': 'raised back of hand',
#  '<f0><9f><91><8b>': 'waving hand',
#  '<f0><9f><91><8f>': 'clapping hands',
#  '<e2><9c><8d>': 'writing hand',
#  '<f0><9f><91><90>': 'open hands',
#  '<f0><9f><99><8c>': 'raising hands',
#  '<f0><9f><99><8f>': 'folded hands',
#  '<f0><9f><a4><9d>': 'handshake',
#  '<f0><9f><92><85>': 'nail polish',
#  '<f0><9f><91><82>': 'ear',
#  '<f0><9f><91><83>': 'nose',
#  '<f0><9f><91><a3>': 'footprints',
#  '<f0><9f><91><80>': 'eyes',
#  '<f0><9f><91><81>': 'eye',
#  '<f0><9f><91><81><ef><b8><8f><e2><80><8d><f0><9f><97><a8><ef><b8><8f>': 'eye in speech bubble',
#  '<f0><9f><91><85>': 'tongue',
#  '<f0><9f><91><84>': 'mouth',
#  '<f0><9f><92><8b>': 'kiss mark',
#  '<f0><9f><92><98>': 'heart with arrow',
#  '<e2><9d><a4>': 'red heart',
#  '<f0><9f><92><93>': 'beating heart',
#  '<f0><9f><92><94>': 'broken heart',
#  '<f0><9f><92><95>': 'two hearts',
#  '<f0><9f><92><96>': 'sparkling heart',
#  '<f0><9f><92><97>': 'growing heart',
#  '<f0><9f><92><99>': 'blue heart',
#  '<f0><9f><92><9a>': 'green heart',
#  '<f0><9f><92><9b>': 'yellow heart',
#  '<f0><9f><92><9c>': 'purple heart',
#  '<f0><9f><96><a4>': 'black heart',
#  '<f0><9f><92><9d>': 'heart with ribbon',
#  '<f0><9f><92><9e>': 'revolving hearts',
#  '<f0><9f><92><9f>': 'heart decoration',
#  '<e2><9d><a3>': 'heavy heart exclamation',
#  '<f0><9f><92><8c>': 'love letter',
#  '<f0><9f><92><a4>': 'zzz',
#  '<f0><9f><92><a2>': 'anger symbol',
#  '<f0><9f><92><a3>': 'bomb',
#  '<f0><9f><92><a5>': 'collision',
#  '<f0><9f><92><a6>': 'sweat droplets',
#  '<f0><9f><92><a8>': 'dashing away',
#  '<f0><9f><92><ab>': 'dizzy',
#  '<f0><9f><92><ac>': 'speech balloon',
#  '<f0><9f><97><a8>': 'left speech bubble',
#  '<f0><9f><97><af>': 'right anger bubble',
#  '<f0><9f><92><ad>': 'thought balloon',
#  '<f0><9f><95><b3>': 'hole',
#  '<f0><9f><91><93>': 'glasses',
#  '<f0><9f><95><b6>': 'sunglasses',
#  '<f0><9f><91><94>': 'necktie',
#  '<f0><9f><91><95>': 't-shirt',
#  '<f0><9f><91><96>': 'jeans',
#  '<f0><9f><91><97>': 'dress',
#  '<f0><9f><91><98>': 'kimono',
#  '<f0><9f><91><99>': 'bikini',
#  '<f0><9f><91><9a>': 'womanâ€™s clothes',
#  '<f0><9f><91><9b>': 'purse',
#  '<f0><9f><91><9c>': 'handbag',
#  '<f0><9f><91><9d>': 'clutch bag',
#  '<f0><9f><9b><8d>': 'shopping bags',
#  '<f0><9f><8e><92>': 'school backpack',
#  '<f0><9f><91><9e>': 'manâ€™s shoe',
#  '<f0><9f><91><9f>': 'running shoe',
#  '<f0><9f><91><a0>': 'high-heeled shoe',
#  '<f0><9f><91><a1>': 'womanâ€™s sandal',
#  '<f0><9f><91><a2>': 'womanâ€™s boot',
#  '<f0><9f><91><91>': 'crown',
#  '<f0><9f><91><92>': 'womanâ€™s hat',
#  '<f0><9f><8e><a9>': 'top hat',
#  '<f0><9f><8e><93>': 'graduation cap',
#  '<e2><9b><91>': 'rescue workerâ€™s helmet',
#  '<f0><9f><93><bf>': 'prayer beads',
#  '<f0><9f><92><84>': 'lipstick',
#  '<f0><9f><92><8d>': 'ring',
#  '<f0><9f><92><8e>': 'gem stone',
#  '<f0><9f><90><b5>': 'monkey face',
#  '<f0><9f><90><92>': 'monkey',
#  '<f0><9f><a6><8d>': 'gorilla',
#  '<f0><9f><90><b6>': 'dog face',
#  '<f0><9f><90><95>': 'dog',
#  '<f0><9f><90><a9>': 'poodle',
#  '<f0><9f><90><ba>': 'wolf face',
#  '<f0><9f><a6><8a>': 'fox face',
#  '<f0><9f><90><b1>': 'cat face',
#  '<f0><9f><90><88>': 'cat',
#  '<f0><9f><a6><81>': 'lion face',
#  '<f0><9f><90><af>': 'tiger face',
#  '<f0><9f><90><85>': 'tiger',
#  '<f0><9f><90><86>': 'leopard',
#  '<f0><9f><90><b4>': 'horse face',
#  '<f0><9f><90><8e>': 'horse',
#  '<f0><9f><a6><8c>': 'deer',
#  '<f0><9f><a6><84>': 'unicorn face',
#  '<f0><9f><90><ae>': 'cow face',
#  '<f0><9f><90><82>': 'ox',
#  '<f0><9f><90><83>': 'water buffalo',
#  '<f0><9f><90><84>': 'cow',
#  '<f0><9f><90><b7>': 'pig face',
#  '<f0><9f><90><96>': 'pig',
#  '<f0><9f><90><97>': 'boar',
#  '<f0><9f><90><bd>': 'pig nose',
#  '<f0><9f><90><8f>': 'ram',
#  '<f0><9f><90><91>': 'sheep',
#  '<f0><9f><90><90>': 'goat',
#  '<f0><9f><90><aa>': 'camel',
#  '<f0><9f><90><ab>': 'two-hump camel',
#  '<f0><9f><90><98>': 'elephant',
#  '<f0><9f><a6><8f>': 'rhinoceros',
#  '<f0><9f><90><ad>': 'mouse face',
#  '<f0><9f><90><81>': 'mouse',
#  '<f0><9f><90><80>': 'rat',
#  '<f0><9f><90><b9>': 'hamster face',
#  '<f0><9f><90><b0>': 'rabbit face',
#  '<f0><9f><90><87>': 'rabbit',
#  '<f0><9f><90><bf>': 'chipmunk',
#  '<f0><9f><a6><87>': 'bat',
#  '<f0><9f><90><bb>': 'bear face',
#  '<f0><9f><90><a8>': 'koala',
#  '<f0><9f><90><bc>': 'panda face',
#  '<f0><9f><90><be>': 'paw prints',
#  '<f0><9f><a6><83>': 'turkey',
#  '<f0><9f><90><94>': 'chicken',
#  '<f0><9f><90><93>': 'rooster',
#  '<f0><9f><90><a3>': 'hatching chick',
#  '<f0><9f><90><a4>': 'baby chick',
#  '<f0><9f><90><a5>': 'front-facing baby chick',
#  '<f0><9f><90><a6>': 'bird',
#  '<f0><9f><90><a7>': 'penguin',
#  '<f0><9f><95><8a>': 'dove',
#  '<f0><9f><a6><85>': 'eagle',
#  '<f0><9f><a6><86>': 'duck',
#  '<f0><9f><a6><89>': 'owl',
#  '<f0><9f><90><b8>': 'frog face',
#  '<f0><9f><90><8a>': 'crocodile',
#  '<f0><9f><90><a2>': 'turtle',
#  '<f0><9f><a6><8e>': 'lizard',
#  '<f0><9f><90><8d>': 'snake',
#  '<f0><9f><90><b2>': 'dragon face',
#  '<f0><9f><90><89>': 'dragon',
#  '<f0><9f><90><b3>': 'spouting whale',
#  '<f0><9f><90><8b>': 'whale',
#  '<f0><9f><90><ac>': 'dolphin',
#  '<f0><9f><90><9f>': 'fish',
#  '<f0><9f><90><a0>': 'tropical fish',
#  '<f0><9f><90><a1>': 'blowfish',
#  '<f0><9f><a6><88>': 'shark',
#  '<f0><9f><90><99>': 'octopus',
#  '<f0><9f><90><9a>': 'spiral shell',
#  '<f0><9f><a6><80>': 'crab',
#  '<f0><9f><a6><90>': 'shrimp',
#  '<f0><9f><a6><91>': 'squid',
#  '<f0><9f><a6><8b>': 'butterfly',
#  '<f0><9f><90><8c>': 'snail',
#  '<f0><9f><90><9b>': 'bug',
#  '<f0><9f><90><9c>': 'ant',
#  '<f0><9f><90><9d>': 'honeybee',
#  '<f0><9f><90><9e>': 'lady beetle',
#  '<f0><9f><95><b7>': 'spider',
#  '<f0><9f><95><b8>': 'spider web',
#  '<f0><9f><a6><82>': 'scorpion',
#  '<f0><9f><92><90>': 'bouquet',
#  '<f0><9f><8c><b8>': 'cherry blossom',
#  '<f0><9f><92><ae>': 'white flower',
#  '<f0><9f><8f><b5>': 'rosette',
#  '<f0><9f><8c><b9>': 'rose',
#  '<f0><9f><a5><80>': 'wilted flower',
#  '<f0><9f><8c><ba>': 'hibiscus',
#  '<f0><9f><8c><bb>': 'sunflower',
#  '<f0><9f><8c><bc>': 'blossom',
#  '<f0><9f><8c><b7>': 'tulip',
#  '<f0><9f><8c><b1>': 'seedling',
#  '<f0><9f><8c><b2>': 'evergreen tree',
#  '<f0><9f><8c><b3>': 'deciduous tree',
#  '<f0><9f><8c><b4>': 'palm tree',
#  '<f0><9f><8c><b5>': 'cactus',
#  '<f0><9f><8c><be>': 'sheaf of rice',
#  '<f0><9f><8c><bf>': 'herb',
#  '<e2><98><98>': 'shamrock',
#  '<f0><9f><8d><80>': 'four leaf clover',
#  '<f0><9f><8d><81>': 'maple leaf',
#  '<f0><9f><8d><82>': 'fallen leaf',
#  '<f0><9f><8d><83>': 'leaf fluttering in wind',
#  '<f0><9f><8d><87>': 'grapes',
#  '<f0><9f><8d><88>': 'melon',
#  '<f0><9f><8d><89>': 'watermelon',
#  '<f0><9f><8d><8a>': 'tangerine',
#  '<f0><9f><8d><8b>': 'lemon',
#  '<f0><9f><8d><8c>': 'banana',
#  '<f0><9f><8d><8d>': 'pineapple',
#  '<f0><9f><8d><8e>': 'red apple',
#  '<f0><9f><8d><8f>': 'green apple',
#  '<f0><9f><8d><90>': 'pear',
#  '<f0><9f><8d><91>': 'peach',
#  '<f0><9f><8d><92>': 'cherries',
#  '<f0><9f><8d><93>': 'strawberry',
#  '<f0><9f><a5><9d>': 'kiwi fruit',
#  '<f0><9f><8d><85>': 'tomato',
#  '<f0><9f><a5><91>': 'avocado',
#  '<f0><9f><8d><86>': 'eggplant',
#  '<f0><9f><a5><94>': 'potato',
#  '<f0><9f><a5><95>': 'carrot',
#  '<f0><9f><8c><bd>': 'ear of corn',
#  '<f0><9f><8c><b6>': 'hot pepper',
#  '<f0><9f><a5><92>': 'cucumber',
#  '<f0><9f><8d><84>': 'mushroom',
#  '<f0><9f><a5><9c>': 'peanuts',
#  '<f0><9f><8c><b0>': 'chestnut',
#  '<f0><9f><8d><9e>': 'bread',
#  '<f0><9f><a5><90>': 'croissant',
#  '<f0><9f><a5><96>': 'baguette bread',
#  '<f0><9f><a5><9e>': 'pancakes',
#  '<f0><9f><a7><80>': 'cheese wedge',
#  '<f0><9f><8d><96>': 'meat on bone',
#  '<f0><9f><8d><97>': 'poultry leg',
#  '<f0><9f><a5><93>': 'bacon',
#  '<f0><9f><8d><94>': 'hamburger',
#  '<f0><9f><8d><9f>': 'french fries',
#  '<f0><9f><8d><95>': 'pizza',
#  '<f0><9f><8c><ad>': 'hot dog',
#  '<f0><9f><8c><ae>': 'taco',
#  '<f0><9f><8c><af>': 'burrito',
#  '<f0><9f><a5><99>': 'stuffed flatbread',
#  '<f0><9f><a5><9a>': 'egg',
#  '<f0><9f><8d><b3>': 'cooking',
#  '<f0><9f><a5><98>': 'shallow pan of food',
#  '<f0><9f><8d><b2>': 'pot of food',
#  '<f0><9f><a5><97>': 'green salad',
#  '<f0><9f><8d><bf>': 'popcorn',
#  '<f0><9f><8d><b1>': 'bento box',
#  '<f0><9f><8d><98>': 'rice cracker',
#  '<f0><9f><8d><99>': 'rice ball',
#  '<f0><9f><8d><9a>': 'cooked rice',
#  '<f0><9f><8d><9b>': 'curry rice',
#  '<f0><9f><8d><9c>': 'steaming bowl',
#  '<f0><9f><8d><9d>': 'spaghetti',
#  '<f0><9f><8d><a0>': 'roasted sweet potato',
#  '<f0><9f><8d><a2>': 'oden',
#  '<f0><9f><8d><a3>': 'sushi',
#  '<f0><9f><8d><a4>': 'fried shrimp',
#  '<f0><9f><8d><a5>': 'fish cake with swirl',
#  '<f0><9f><8d><a1>': 'dango',
#  '<f0><9f><8d><a6>': 'soft ice cream',
#  '<f0><9f><8d><a7>': 'shaved ice',
#  '<f0><9f><8d><a8>': 'ice cream',
#  '<f0><9f><8d><a9>': 'doughnut',
#  '<f0><9f><8d><aa>': 'cookie',
#  '<f0><9f><8e><82>': 'birthday cake',
#  '<f0><9f><8d><b0>': 'shortcake',
#  '<f0><9f><8d><ab>': 'chocolate bar',
#  '<f0><9f><8d><ac>': 'candy',
#  '<f0><9f><8d><ad>': 'lollipop',
#  '<f0><9f><8d><ae>': 'custard',
#  '<f0><9f><8d><af>': 'honey pot',
#  '<f0><9f><8d><bc>': 'baby bottle',
#  '<f0><9f><a5><9b>': 'glass of milk',
#  '<e2><98><95>': 'hot beverage',
#  '<f0><9f><8d><b5>': 'teacup without handle',
#  '<f0><9f><8d><b6>': 'sake',
#  '<f0><9f><8d><be>': 'bottle with popping cork',
#  '<f0><9f><8d><b7>': 'wine glass',
#  '<f0><9f><8d><b8>': 'cocktail glass',
#  '<f0><9f><8d><b9>': 'tropical drink',
#  '<f0><9f><8d><ba>': 'beer mug',
#  '<f0><9f><8d><bb>': 'clinking beer mugs',
#  '<f0><9f><a5><82>': 'clinking glasses',
#  '<f0><9f><a5><83>': 'tumbler glass',
#  '<f0><9f><8d><bd>': 'fork and knife with plate',
#  '<f0><9f><8d><b4>': 'fork and knife',
#  '<f0><9f><a5><84>': 'spoon',
#  '<f0><9f><94><aa>': 'kitchen knife',
#  '<f0><9f><8f><ba>': 'amphora',
#  '<f0><9f><8c><8d>': 'globe showing europe-africa',
#  '<f0><9f><8c><8e>': 'globe showing americas',
#  '<f0><9f><8c><8f>': 'globe showing asia-australia',
#  '<f0><9f><8c><90>': 'globe with meridians',
#  '<f0><9f><97><ba>': 'world map',
#  '<f0><9f><97><be>': 'map of japan',
#  '<f0><9f><8f><94>': 'snow-capped mountain',
#  '<e2><9b><b0>': 'mountain',
#  '<f0><9f><8c><8b>': 'volcano',
#  '<f0><9f><97><bb>': 'mount fuji',
#  '<f0><9f><8f><95>': 'camping',
#  '<f0><9f><8f><96>': 'beach with umbrella',
#  '<f0><9f><8f><9c>': 'desert',
#  '<f0><9f><8f><9d>': 'desert island',
#  '<f0><9f><8f><9e>': 'national park',
#  '<f0><9f><8f><9f>': 'stadium',
#  '<f0><9f><8f><9b>': 'classical building',
#  '<f0><9f><8f><97>': 'building construction',
#  '<f0><9f><8f><98>': 'house',
#  '<f0><9f><8f><99>': 'cityscape',
#  '<f0><9f><8f><9a>': 'derelict house',
#  '<f0><9f><8f><a0>': 'house',
#  '<f0><9f><8f><a1>': 'house with garden',
#  '<f0><9f><8f><a2>': 'office building',
#  '<f0><9f><8f><a3>': 'japanese post office',
#  '<f0><9f><8f><a4>': 'post office',
#  '<f0><9f><8f><a5>': 'hospital',
#  '<f0><9f><8f><a6>': 'bank',
#  '<f0><9f><8f><a8>': 'hotel',
#  '<f0><9f><8f><a9>': 'love hotel',
#  '<f0><9f><8f><aa>': 'convenience store',
#  '<f0><9f><8f><ab>': 'school',
#  '<f0><9f><8f><ac>': 'department store',
#  '<f0><9f><8f><ad>': 'factory',
#  '<f0><9f><8f><af>': 'japanese castle',
#  '<f0><9f><8f><b0>': 'castle',
#  '<f0><9f><92><92>': 'wedding',
#  '<f0><9f><97><bc>': 'tokyo tower',
#  '<f0><9f><97><bd>': 'statue of liberty',
#  '<e2><9b><aa>': 'church',
#  '<f0><9f><95><8c>': 'mosque',
#  '<f0><9f><95><8d>': 'synagogue',
#  '<e2><9b><a9>': 'shinto shrine',
#  '<f0><9f><95><8b>': 'kaaba',
#  '<e2><9b><b2>': 'fountain',
#  '<e2><9b><ba>': 'tent',
#  '<f0><9f><8c><81>': 'foggy',
#  '<f0><9f><8c><83>': 'night with stars',
#  '<f0><9f><8c><84>': 'sunrise over mountains',
#  '<f0><9f><8c><85>': 'sunrise',
#  '<f0><9f><8c><86>': 'cityscape at dusk',
#  '<f0><9f><8c><87>': 'sunset',
#  '<f0><9f><8c><89>': 'bridge at night',
#  '<e2><99><a8>': 'hot springs',
#  '<f0><9f><8c><8c>': 'milky way',
#  '<f0><9f><8e><a0>': 'carousel horse',
#  '<f0><9f><8e><a1>': 'ferris wheel',
#  '<f0><9f><8e><a2>': 'roller coaster',
#  '<f0><9f><92><88>': 'barber pole',
#  '<f0><9f><8e><aa>': 'circus tent',
#  '<f0><9f><8e><ad>': 'performing arts',
#  '<f0><9f><96><bc>': 'framed picture',
#  '<f0><9f><8e><a8>': 'artist palette',
#  '<f0><9f><8e><b0>': 'slot machine',
#  '<f0><9f><9a><82>': 'locomotive',
#  '<f0><9f><9a><83>': 'railway car',
#  '<f0><9f><9a><84>': 'high-speed train',
#  '<f0><9f><9a><85>': 'high-speed train with bullet nose',
#  '<f0><9f><9a><86>': 'train',
#  '<f0><9f><9a><87>': 'metro',
#  '<f0><9f><9a><88>': 'light rail',
#  '<f0><9f><9a><89>': 'station',
#  '<f0><9f><9a><8a>': 'tram',
#  '<f0><9f><9a><9d>': 'monorail',
#  '<f0><9f><9a><9e>': 'mountain railway',
#  '<f0><9f><9a><8b>': 'tram car',
#  '<f0><9f><9a><8c>': 'bus',
#  '<f0><9f><9a><8d>': 'oncoming bus',
#  '<f0><9f><9a><8e>': 'trolleybus',
#  '<f0><9f><9a><90>': 'minibus',
#  '<f0><9f><9a><91>': 'ambulance',
#  '<f0><9f><9a><92>': 'fire engine',
#  '<f0><9f><9a><93>': 'police car',
#  '<f0><9f><9a><94>': 'oncoming police car',
#  '<f0><9f><9a><95>': 'taxi',
#  '<f0><9f><9a><96>': 'oncoming taxi',
#  '<f0><9f><9a><97>': 'automobile',
#  '<f0><9f><9a><98>': 'oncoming automobile',
#  '<f0><9f><9a><99>': 'sport utility vehicle',
#  '<f0><9f><9a><9a>': 'delivery truck',
#  '<f0><9f><9a><9b>': 'articulated lorry',
#  '<f0><9f><9a><9c>': 'tractor',
#  '<f0><9f><9a><b2>': 'bicycle',
#  '<f0><9f><9b><b4>': 'kick scooter',
#  '<f0><9f><9b><b5>': 'motor scooter',
#  '<f0><9f><9a><8f>': 'bus stop',
#  '<f0><9f><9b><a3>': 'motorway',
#  '<f0><9f><9b><a4>': 'railway track',
#  '<e2><9b><bd>': 'fuel pump',
#  '<f0><9f><9a><a8>': 'police car light',
#  '<f0><9f><9a><a5>': 'horizontal traffic light',
#  '<f0><9f><9a><a6>': 'vertical traffic light',
#  '<f0><9f><9a><a7>': 'construction',
#  '<f0><9f><9b><91>': 'stop sign',
#  '<e2><9a><93>': 'anchor',
#  '<e2><9b><b5>': 'sailboat',
#  '<f0><9f><9b><b6>': 'canoe',
#  '<f0><9f><9a><a4>': 'speedboat',
#  '<f0><9f><9b><b3>': 'passenger ship',
#  '<e2><9b><b4>': 'ferry',
#  '<f0><9f><9b><a5>': 'motor boat',
#  '<f0><9f><9a><a2>': 'ship',
#  '<e2><9c><88>': 'airplane',
#  '<f0><9f><9b><a9>': 'small airplane',
#  '<f0><9f><9b><ab>': 'airplane departure',
#  '<f0><9f><9b><ac>': 'airplane arrival',
#  '<f0><9f><92><ba>': 'seat',
#  '<f0><9f><9a><81>': 'helicopter',
#  '<f0><9f><9a><9f>': 'suspension railway',
#  '<f0><9f><9a><a0>': 'mountain cableway',
#  '<f0><9f><9a><a1>': 'aerial tramway',
#  '<f0><9f><9a><80>': 'rocket',
#  '<f0><9f><9b><b0>': 'satellite',
#  '<f0><9f><9b><8e>': 'bellhop bell',
#  '<f0><9f><9a><aa>': 'door',
#  '<f0><9f><9b><8c>': 'person in bed',
#  '<f0><9f><9b><8f>': 'bed',
#  '<f0><9f><9b><8b>': 'couch and lamp',
#  '<f0><9f><9a><bd>': 'toilet',
#  '<f0><9f><9a><bf>': 'shower',
#  '<f0><9f><9b><80>': 'person taking bath',
#  '<f0><9f><9b><81>': 'bathtub',
#  '<e2><8c><9b>': 'hourglass',
#  '<e2><8f><b3>': 'hourglass with flowing sand',
#  '<e2><8c><9a>': 'watch',
#  '<e2><8f><b0>': 'alarm clock',
#  '<e2><8f><b1>': 'stopwatch',
#  '<e2><8f><b2>': 'timer clock',
#  '<f0><9f><95><b0>': 'mantelpiece clock',
#  '<f0><9f><95><9b>': 'twelve oâ€™clock',
#  '<f0><9f><95><a7>': 'twelve-thirty',
#  '<f0><9f><95><90>': 'one oâ€™clock',
#  '<f0><9f><95><9c>': 'one-thirty',
#  '<f0><9f><95><91>': 'two oâ€™clock',
#  '<f0><9f><95><9d>': 'two-thirty',
#  '<f0><9f><95><92>': 'three oâ€™clock',
#  '<f0><9f><95><9e>': 'three-thirty',
#  '<f0><9f><95><93>': 'four oâ€™clock',
#  '<f0><9f><95><9f>': 'four-thirty',
#  '<f0><9f><95><94>': 'five oâ€™clock',
#  '<f0><9f><95><a0>': 'five-thirty',
#  '<f0><9f><95><95>': 'six oâ€™clock',
#  '<f0><9f><95><a1>': 'six-thirty',
#  '<f0><9f><95><96>': 'seven oâ€™clock',
#  '<f0><9f><95><a2>': 'seven-thirty',
#  '<f0><9f><95><97>': 'eight oâ€™clock',
#  '<f0><9f><95><a3>': 'eight-thirty',
#  '<f0><9f><95><98>': 'nine oâ€™clock',
#  '<f0><9f><95><a4>': 'nine-thirty',
#  '<f0><9f><95><99>': 'ten oâ€™clock',
#  '<f0><9f><95><a5>': 'ten-thirty',
#  '<f0><9f><95><9a>': 'eleven oâ€™clock',
#  '<f0><9f><95><a6>': 'eleven-thirty',
#  '<f0><9f><8c><91>': 'new moon',
#  '<f0><9f><8c><92>': 'waxing crescent moon',
#  '<f0><9f><8c><93>': 'first quarter moon',
#  '<f0><9f><8c><94>': 'waxing gibbous moon',
#  '<f0><9f><8c><95>': 'full moon',
#  '<f0><9f><8c><96>': 'waning gibbous moon',
#  '<f0><9f><8c><97>': 'last quarter moon',
#  '<f0><9f><8c><98>': 'waning crescent moon',
#  '<f0><9f><8c><99>': 'crescent moon',
#  '<f0><9f><8c><9a>': 'new moon face',
#  '<f0><9f><8c><9b>': 'first quarter moon with face',
#  '<f0><9f><8c><9c>': 'last quarter moon with face',
#  '<f0><9f><8c><a1>': 'thermometer',
#  '<e2><98><80>': 'sun',
#  '<f0><9f><8c><9d>': 'full moon with face',
#  '<f0><9f><8c><9e>': 'sun with face',
#  '<e2><ad><90>': 'white medium star',
#  '<f0><9f><8c><9f>': 'glowing star',
#  '<f0><9f><8c><a0>': 'shooting star',
#  '<e2><98><81>': 'cloud',
#  '<e2><9b><85>': 'sun behind cloud',
#  '<e2><9b><88>': 'cloud with lightning and rain',
#  '<f0><9f><8c><a4>': 'sun behind small cloud',
#  '<f0><9f><8c><a5>': 'sun behind large cloud',
#  '<f0><9f><8c><a6>': 'sun behind rain cloud',
#  '<f0><9f><8c><a7>': 'cloud with rain',
#  '<f0><9f><8c><a8>': 'cloud with snow',
#  '<f0><9f><8c><a9>': 'cloud with lightning',
#  '<f0><9f><8c><aa>': 'tornado',
#  '<f0><9f><8c><ab>': 'fog',
#  '<f0><9f><8c><ac>': 'wind face',
#  '<f0><9f><8c><80>': 'cyclone',
#  '<f0><9f><8c><88>': 'rainbow',
#  '<f0><9f><8c><82>': 'closed umbrella',
#  '<e2><98><82>': 'umbrella',
#  '<e2><98><94>': 'umbrella with rain drops',
#  '<e2><9b><b1>': 'umbrella on ground',
#  '<e2><9a><a1>': 'high voltage',
#  '<e2><9d><84>': 'snowflake',
#  '<e2><98><83>': 'snowman',
#  '<e2><9b><84>': 'snowman without snow',
#  '<e2><98><84>': 'comet',
#  '<f0><9f><94><a5>': 'fire',
#  '<f0><9f><92><a7>': 'droplet',
#  '<f0><9f><8c><8a>': 'water wave',
#  '<f0><9f><8e><83>': 'jack-o-lantern',
#  '<f0><9f><8e><84>': 'christmas tree',
#  '<f0><9f><8e><86>': 'fireworks',
#  '<f0><9f><8e><87>': 'sparkler',
#  '<e2><9c><a8>': 'sparkles',
#  '<f0><9f><8e><88>': 'balloon',
#  '<f0><9f><8e><89>': 'party popper',
#  '<f0><9f><8e><8a>': 'confetti ball',
#  '<f0><9f><8e><8b>': 'tanabata tree',
#  '<f0><9f><8e><8d>': 'pine decoration',
#  '<f0><9f><8e><8e>': 'japanese dolls',
#  '<f0><9f><8e><8f>': 'carp streamer',
#  '<f0><9f><8e><90>': 'wind chime',
#  '<f0><9f><8e><91>': 'moon viewing ceremony',
#  '<f0><9f><8e><80>': 'ribbon',
#  '<f0><9f><8e><81>': 'wrapped gift',
#  '<f0><9f><8e><97>': 'reminder ribbon',
#  '<f0><9f><8e><9f>': 'admission tickets',
#  '<f0><9f><8e><ab>': 'ticket',
#  '<f0><9f><8e><96>': 'military medal',
#  '<f0><9f><8f><86>': 'trophy',
#  '<f0><9f><8f><85>': 'sports medal',
#  '<f0><9f><a5><87>': '1st place medal',
#  '<f0><9f><a5><88>': '2nd place medal',
#  '<f0><9f><a5><89>': '3rd place medal',
#  '<e2><9a><bd>': 'soccer ball',
#  '<e2><9a><be>': 'baseball',
#  '<f0><9f><8f><80>': 'basketball',
#  '<f0><9f><8f><90>': 'volleyball',
#  '<f0><9f><8f><88>': 'american football',
#  '<f0><9f><8f><89>': 'rugby football',
#  '<f0><9f><8e><be>': 'tennis',
#  '<f0><9f><8e><b1>': 'pool 8 ball',
#  '<f0><9f><8e><b3>': 'bowling',
#  '<f0><9f><8f><8f>': 'cricket',
#  '<f0><9f><8f><91>': 'field hockey',
#  '<f0><9f><8f><92>': 'ice hockey',
#  '<f0><9f><8f><93>': 'ping pong',
#  '<f0><9f><8f><b8>': 'badminton',
#  '<f0><9f><a5><8a>': 'boxing glove',
#  '<f0><9f><a5><8b>': 'martial arts uniform',
#  '<f0><9f><a5><85>': 'goal net',
#  '<f0><9f><8e><af>': 'direct hit',
#  '<e2><9b><b3>': 'flag in hole',
#  '<e2><9b><b8>': 'ice skate',
#  '<f0><9f><8e><a3>': 'fishing pole',
#  '<f0><9f><8e><bd>': 'running shirt',
#  '<f0><9f><8e><bf>': 'skis',
#  '<f0><9f><8e><ae>': 'video game',
#  '<f0><9f><95><b9>': 'joystick',
#  '<f0><9f><8e><b2>': 'game die',
#  '<e2><99><a0>': 'spade suit',
#  '<e2><99><a5>': 'heart suit',
#  '<e2><99><a6>': 'diamond suit',
#  '<e2><99><a3>': 'club suit',
#  '<f0><9f><83><8f>': 'joker',
#  '<f0><9f><80><84>': 'mahjong red dragon',
#  '<f0><9f><8e><b4>': 'flower playing cards',
#  '<f0><9f><94><87>': 'muted speaker',
#  '<f0><9f><94><88>': 'speaker low volume',
#  '<f0><9f><94><89>': 'speaker medium volume',
#  '<f0><9f><94><8a>': 'speaker high volume',
#  '<f0><9f><93><a2>': 'loudspeaker',
#  '<f0><9f><93><a3>': 'megaphone',
#  '<f0><9f><93><af>': 'postal horn',
#  '<f0><9f><94><94>': 'bell',
#  '<f0><9f><94><95>': 'bell with slash',
#  '<f0><9f><8e><bc>': 'musical score',
#  '<f0><9f><8e><b5>': 'musical note',
#  '<f0><9f><8e><b6>': 'musical notes',
#  '<f0><9f><8e><99>': 'studio microphone',
#  '<f0><9f><8e><9a>': 'level slider',
#  '<f0><9f><8e><9b>': 'control knobs',
#  '<f0><9f><8e><a4>': 'microphone',
#  '<f0><9f><8e><a7>': 'headphone',
#  '<f0><9f><93><bb>': 'radio',
#  '<f0><9f><8e><b7>': 'saxophone',
#  '<f0><9f><8e><b8>': 'guitar',
#  '<f0><9f><8e><b9>': 'musical keyboard',
#  '<f0><9f><8e><ba>': 'trumpet',
#  '<f0><9f><8e><bb>': 'violin',
#  '<f0><9f><a5><81>': 'drum',
#  '<f0><9f><93><b1>': 'mobile phone',
#  '<f0><9f><93><b2>': 'mobile phone with arrow',
#  '<e2><98><8e>': 'telephone',
#  '<f0><9f><93><9e>': 'telephone receiver',
#  '<f0><9f><93><9f>': 'pager',
#  '<f0><9f><93><a0>': 'fax machine',
#  '<f0><9f><94><8b>': 'battery',
#  '<f0><9f><94><8c>': 'electric plug',
#  '<f0><9f><92><bb>': 'laptop computer',
#  '<f0><9f><96><a5>': 'desktop computer',
#  '<f0><9f><96><a8>': 'printer',
#  '<e2><8c><a8>': 'keyboard',
#  '<f0><9f><96><b1>': 'computer mouse',
#  '<f0><9f><96><b2>': 'trackball',
#  '<f0><9f><92><bd>': 'computer disk',
#  '<f0><9f><92><be>': 'floppy disk',
#  '<f0><9f><92><bf>': 'optical disk',
#  '<f0><9f><93><80>': 'dvd',
#  '<f0><9f><8e><a5>': 'movie camera',
#  '<f0><9f><8e><9e>': 'film frames',
#  '<f0><9f><93><bd>': 'film projector',
#  '<f0><9f><8e><ac>': 'clapper board',
#  '<f0><9f><93><ba>': 'television',
#  '<f0><9f><93><b7>': 'camera',
#  '<f0><9f><93><b8>': 'camera with flash',
#  '<f0><9f><93><b9>': 'video camera',
#  '<f0><9f><93><bc>': 'videocassette',
#  '<f0><9f><94><8d>': 'left-pointing magnifying glass',
#  '<f0><9f><94><8e>': 'right-pointing magnifying glass',
#  '<f0><9f><94><ac>': 'microscope',
#  '<f0><9f><94><ad>': 'telescope',
#  '<f0><9f><93><a1>': 'satellite antenna',
#  '<f0><9f><95><af>': 'candle',
#  '<f0><9f><92><a1>': 'light bulb',
#  '<f0><9f><94><a6>': 'flashlight',
#  '<f0><9f><8f><ae>': 'red paper lantern',
#  '<f0><9f><93><94>': 'notebook with decorative cover',
#  '<f0><9f><93><95>': 'closed book',
#  '<f0><9f><93><96>': 'open book',
#  '<f0><9f><93><97>': 'green book',
#  '<f0><9f><93><98>': 'blue book',
#  '<f0><9f><93><99>': 'orange book',
#  '<f0><9f><93><9a>': 'books',
#  '<f0><9f><93><93>': 'notebook',
#  '<f0><9f><93><92>': 'ledger',
#  '<f0><9f><93><83>': 'page with curl',
#  '<f0><9f><93><9c>': 'scroll',
#  '<f0><9f><93><84>': 'page facing up',
#  '<f0><9f><93><b0>': 'newspaper',
#  '<f0><9f><97><9e>': 'rolled-up newspaper',
#  '<f0><9f><93><91>': 'bookmark tabs',
#  '<f0><9f><94><96>': 'bookmark',
#  '<f0><9f><8f><b7>': 'label',
#  '<f0><9f><92><b0>': 'money bag',
#  '<f0><9f><92><b4>': 'yen banknote',
#  '<f0><9f><92><b5>': 'dollar banknote',
#  '<f0><9f><92><b6>': 'euro banknote',
#  '<f0><9f><92><b7>': 'pound banknote',
#  '<f0><9f><92><b8>': 'money with wings',
#  '<f0><9f><92><b3>': 'credit card',
#  '<f0><9f><92><b9>': 'chart increasing with yen',
#  '<f0><9f><92><b1>': 'currency exchange',
#  '<f0><9f><92><b2>': 'heavy dollar sign',
#  '<e2><9c><89>': 'envelope',
#  '<f0><9f><93><a7>': 'e-mail',
#  '<f0><9f><93><a8>': 'incoming envelope',
#  '<f0><9f><93><a9>': 'envelope with arrow',
#  '<f0><9f><93><a4>': 'outbox tray',
#  '<f0><9f><93><a5>': 'inbox tray',
#  '<f0><9f><93><a6>': 'package',
#  '<f0><9f><93><ab>': 'closed mailbox with raised flag',
#  '<f0><9f><93><aa>': 'closed mailbox with lowered flag',
#  '<f0><9f><93><ac>': 'open mailbox with raised flag',
#  '<f0><9f><93><ad>': 'open mailbox with lowered flag',
#  '<f0><9f><93><ae>': 'postbox',
#  '<f0><9f><97><b3>': 'ballot box with ballot',
#  '<e2><9c><8f>': 'pencil',
#  '<e2><9c><92>': 'black nib',
#  '<f0><9f><96><8b>': 'fountain pen',
#  '<f0><9f><96><8a>': 'pen',
#  '<f0><9f><96><8c>': 'paintbrush',
#  '<f0><9f><96><8d>': 'crayon',
#  '<f0><9f><93><9d>': 'memo',
#  '<f0><9f><92><bc>': 'briefcase',
#  '<f0><9f><93><81>': 'file folder',
#  '<f0><9f><93><82>': 'open file folder',
#  '<f0><9f><97><82>': 'card index dividers',
#  '<f0><9f><93><85>': 'calendar',
#  '<f0><9f><93><86>': 'tear-off calendar',
#  '<f0><9f><97><92>': 'spiral notepad',
#  '<f0><9f><97><93>': 'spiral calendar',
#  '<f0><9f><93><87>': 'card index',
#  '<f0><9f><93><88>': 'chart increasing',
#  '<f0><9f><93><89>': 'chart decreasing',
#  '<f0><9f><93><8a>': 'bar chart',
#  '<f0><9f><93><8b>': 'clipboard',
#  '<f0><9f><93><8c>': 'pushpin',
#  '<f0><9f><93><8d>': 'round pushpin',
#  '<f0><9f><93><8e>': 'paperclip',
#  '<f0><9f><96><87>': 'linked paperclips',
#  '<f0><9f><93><8f>': 'straight ruler',
#  '<f0><9f><93><90>': 'triangular ruler',
#  '<e2><9c><82>': 'scissors',
#  '<f0><9f><97><83>': 'card file box',
#  '<f0><9f><97><84>': 'file cabinet',
#  '<f0><9f><97><91>': 'wastebasket',
#  '<f0><9f><94><92>': 'locked',
#  '<f0><9f><94><93>': 'unlocked',
#  '<f0><9f><94><8f>': 'locked with pen',
#  '<f0><9f><94><90>': 'locked with key',
#  '<f0><9f><94><91>': 'key',
#  '<f0><9f><97><9d>': 'old key',
#  '<f0><9f><94><a8>': 'hammer',
#  '<e2><9b><8f>': 'pick',
#  '<e2><9a><92>': 'hammer and pick',
#  '<f0><9f><9b><a0>': 'hammer and wrench',
#  '<f0><9f><97><a1>': 'dagger',
#  '<e2><9a><94>': 'crossed swords',
#  '<f0><9f><94><ab>': 'pistol',
#  '<f0><9f><8f><b9>': 'bow and arrow',
#  '<f0><9f><9b><a1>': 'shield',
#  '<f0><9f><94><a7>': 'wrench',
#  '<f0><9f><94><a9>': 'nut and bolt',
#  '<e2><9a><99>': 'gear',
#  '<f0><9f><97><9c>': 'clamp',
#  '<e2><9a><97>': 'alembic',
#  '<e2><9a><96>': 'balance scale',
#  '<f0><9f><94><97>': 'link',
#  '<e2><9b><93>': 'chains',
#  '<f0><9f><92><89>': 'syringe',
#  '<f0><9f><92><8a>': 'pill',
#  '<f0><9f><9a><ac>': 'cigarette',
#  '<e2><9a><b0>': 'coffin',
#  '<e2><9a><b1>': 'funeral urn',
#  '<f0><9f><97><bf>': 'moai',
#  '<f0><9f><9b><a2>': 'oil drum',
#  '<f0><9f><94><ae>': 'crystal ball',
#  '<f0><9f><9b><92>': 'shopping cart',
#  '<f0><9f><8f><a7>': 'atm sign',
#  '<f0><9f><9a><ae>': 'litter in bin sign',
#  '<f0><9f><9a><b0>': 'potable water',
#  '<e2><99><bf>': 'wheelchair symbol',
#  '<f0><9f><9a><b9>': 'menâ€™s room',
#  '<f0><9f><9a><ba>': 'womenâ€™s room',
#  '<f0><9f><9a><bb>': 'restroom',
#  '<f0><9f><9a><bc>': 'baby symbol',
#  '<f0><9f><9a><be>': 'water closet',
#  '<f0><9f><9b><82>': 'passport control',
#  '<f0><9f><9b><83>': 'customs',
#  '<f0><9f><9b><84>': 'baggage claim',
#  '<f0><9f><9b><85>': 'left luggage',
#  '<e2><9a><a0>': 'warning',
#  '<f0><9f><9a><b8>': 'children crossing',
#  '<e2><9b><94>': 'no entry',
#  ...}

# %%
encoding = df_emojis['encoding'].tolist()

# %%
tweets = df_tweets['text'].tolist()

# %%
final_emojis = []
for i,tweet in enumerate(tweets):
    if i % 10000 == 0:
        print(i)
    emojis = []
    for enc in encoding:
        matchList = re.findall(enc, tweet, flags=0)
        if len(matchList) == 0:
            pass
        else:
            emojis.append(matchList)
    final_emojis.append(emojis)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000

# %%
emojis = list(itertools.chain.from_iterable(final_emojis))

# %%
count = []
emoji_desc = []

# %%
for em in final_emojis:
    if len(em) == 0:
        count.append(0)
        emoji_desc.append('None')
    else:
        string =""
        for emoji in em:
            count.append(len(emoji))
            for e in emoji:
                
                desc = emoji_dict[e]
                string += desc + "%"
        emoji_desc.append(string)

# %%
#df_tweets['count_raw'] = pd.DataFrame(count)
df_tweets['description_raw'] = pd.DataFrame(emoji_desc)

# %%
emoji_split = []
for emoji in emoji_desc:
    emoji_split.append(emoji.split("%"))

# %%
final_emoji_processed = []
for em in emoji_split:
    current_emoji = []
    for dec in em:
        if dec != '':
            current_emoji.append(dec)
    final_emoji_processed.append(current_emoji)

# %%
count = []
for em in final_emoji_processed:
    if len(em) > 1:
        count.append(len(em))
    else:
        for emo in em:
            if emo == 'None':
                count.append(0)
            else:
                count.append(1)

# %%
df_tweets['count_raw'] = pd.DataFrame(count)

# %%
final_emoji_processed[count.index(6)]
# Out:
# ['face with tears of joy',
#  'face with tears of joy',
#  'face with tears of joy',
#  'face with tears of joy',
#  'face with tears of joy',
#  'face with tears of joy']

# %%
text = df_tweets['text'].tolist()
labels =df_tweets['labels'].tolist()
post_time = df_tweets['posted_time'].tolist()
locations = df_tweets['locations'].tolist()
lat = df_tweets['latitude'].tolist()
long = df_tweets['longitude'].tolist()

# %%
from collections import Counter
z = Counter(final_emoji_processed[0])
len(z)
# Out:
# 2

# %%
for k,v in z.items():
    print(k,v)
# Out:
# person shrugging 2
# female sign 2

# %% [markdown]
# # make the duplicates - Sometimes a single tweet might contain more than one type of emoji. This created copies of the tweet with different emojis referenced to it

# %%
new_text = []
new_labels = []
new_post_time = []
new_locations = []
new_lat = []
new_long = []
new_count = []
new_description = []

# %%
for i in range(len(text)):
    key_list = Counter(final_emoji_processed[i])
    if len(key_list) == 1:
        new_text.append(text[i])
        new_labels.append(labels[i])
        new_post_time.append(post_time[i])
        new_locations.append(locations[i])
        new_lat.append(lat[i])
        new_long.append(long[i])
        for k,v in key_list.items():
            new_description.append(k)
            new_count.append(v)
    else:
        for j in range(len(key_list)):
            new_text.append(text[i])
            new_labels.append(labels[i])
            new_post_time.append(post_time[i])
            new_locations.append(locations[i])
            new_lat.append(lat[i])
            new_long.append(long[i])
        for k,v in key_list.items():
            new_description.append(k)
            new_count.append(v)

# %%
df_dup = pd.DataFrame(index=range(len(new_text)))

# %%
df_dup['text'] = pd.DataFrame(new_text)
df_dup['labels'] = pd.DataFrame(new_labels)
df_dup['posted_time'] = pd.DataFrame(new_post_time)
df_dup['locations'] = pd.DataFrame(new_locations)
df_dup['latitude'] = pd.DataFrame(new_lat)
df_dup['longitude'] = pd.DataFrame(new_long)
df_dup['count'] = pd.DataFrame(new_count)
df_dup['description'] = pd.DataFrame(new_description)

# %%
df_dup.to_csv('duplicates_irma_timeseries.csv',index=False)
